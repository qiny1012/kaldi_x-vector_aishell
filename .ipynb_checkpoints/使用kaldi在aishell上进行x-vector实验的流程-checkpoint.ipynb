# %% [markdown]
# ## 使用kaldi中x-vector方法在aishell数据库上训练说话人识别模型
#
#     VAD，MFCC特征
#     采用数据增强手段 ，加入噪音，模拟混响
#     x-vector
#     LDA,PLDA
#     EER,minDCF

# %% [markdown]
# **第一步：** 准备数据配置索引文件
#
#     使用脚本生成下面的索引文件
#
#     data
#     ├── test
#     │   ├── spk2utt
#     │   ├── text
#     │   ├── utt2spk
#     │   └── wav.scp
#     └── train
#         ├── spk2utt
#         ├── text
#         ├── utt2spk
#         └── wav.scp

# %%
# !chmod +x new_01_prepare_train_index.sh
# !./new_01_prepare_train_index.sh
# Out:
# Preparing data/local/train transcriptions
# Preparing data/local/test transcriptions
# local/aishell_data_prep.sh: AISHELL data preparation succeeded

# %% [markdown]
# **第二步：** 准备原始语音的mfcc表征，并进行VAD操作
#
#     mfcc的参数：
#     --sample-frequency=16000
#     --frame-length=25 # the default is 25
#     --low-freq=20 # the default.
#     --high-freq=8000 # the default is zero meaning use the Nyquist (4k in this case).
#     --num-ceps=23 # higher than the default which is 12.
#     --snip-edges=false
#     vad的参数：
#     --vad-energy-threshold=5.5
#     --vad-energy-mean-scale=0.5
#     --vad-proportion-threshold=0.12
#     --vad-frames-context=2

# %%
import time

ss = time.time()
# !chmod +x new_02_generate_mfcc_and_vad.sh
# !./new_02_generate_mfcc_and_vad.sh

print("耗时：",time.time() - ss)

## 用时：1150s，
# Out:
# steps/make_mfcc.sh --write-utt2num-frames true --mfcc-config conf/mfcc.conf --nj 20 --cmd run.pl --mem 10G data/train exp/make_mfcc feature/mfcc
# utils/validate_data_dir.sh: Successfully validated data-directory data/train
# steps/make_mfcc.sh: [info]: no segments file exists: assuming wav.scp indexed by utterance.
# steps/make_mfcc.sh: Succeeded creating MFCC features for train
# fix_data_dir.sh: kept all 120098 utterances.
# fix_data_dir.sh: old files are kept in data/train/.backup
# sid/compute_vad_decision.sh --nj 20 --cmd run.pl --mem 10G data/train exp/make_vad feature/mfcc
# Created VAD output for train
# fix_data_dir.sh: kept all 120098 utterances.
# fix_data_dir.sh: old files are kept in data/train/.backup
# steps/make_mfcc.sh --write-utt2num-frames true --mfcc-config conf/mfcc.conf --nj 20 --cmd run.pl --mem 10G data/test exp/make_mfcc feature/mfcc
# utils/validate_data_dir.sh: Successfully validated data-directory data/test
# steps/make_mfcc.sh: [info]: no segments file exists: assuming wav.scp indexed by utterance.
# steps/make_mfcc.sh: Succeeded creating MFCC features for test
# fix_data_dir.sh: kept all 7176 utterances.
# fix_data_dir.sh: old files are kept in data/test/.backup
# sid/compute_vad_decision.sh --nj 20 --cmd run.pl --mem 10G data/test exp/make_vad feature/mfcc
# Created VAD output for test
# fix_data_dir.sh: kept all 7176 utterances.
# fix_data_dir.sh: old files are kept in data/test/.backup
# 耗时： 1150.3151621818542

# %% [markdown]
# **第三步：** 生成带有混响和噪音的索引文件
#
#     1. 按照1：1的数量，生成带有混响的语音
#     2. 按照1：3的数量，生成带有各种噪音的语音
#
#     data中出现增加混响的配置文件，增加噪音的配置文件（data/train_reverb data/train_noise data/train_music data/train_babble）
#     将4种增强的数据组合到一个文件中data/train_aug
#     注意，此时并没有提取mfcc特征，仅仅是设计了如何扩充数据。

# %%
ss = time.time()

# !chmod +x new_03_prepare_aug_data.sh
# !./new_03_prepare_aug_data.sh

print("耗时：",time.time() - ss)
# Out:
# steps/data/reverberate_data_dir.py:8: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import argparse, shlex, glob, math, os, random, sys, warnings, copy, imp, ast
# steps/data/reverberate_data_dir.py --rir-set-parameters 0.5, /home/qinyc/openSLR/SLR28_rir/RIRS_NOISES/simulated_rirs/smallroom/rir_list --rir-set-parameters 0.5, /home/qinyc/openSLR/SLR28_rir/RIRS_NOISES/simulated_rirs/mediumroom/rir_list --speech-rvb-probability 1 --pointsource-noise-addition-probability 0 --isotropic-noise-addition-probability 0 --num-replications 1 --source-sampling-rate 16000 data/train data/train_reverb
# Number of RIRs is 40000
# Getting the duration of the recordings...
# utils/copy_data_dir.sh: copied data from data/train_reverb to data/train_reverb.new
# utils/validate_data_dir.sh: Successfully validated data-directory data/train_reverb.new
# ./new_03_prepare_dataaugment.sh: 19: ./new_03_prepare_dataaugment.sh: Prepare: not found
# ./new_03_prepare_dataaugment.sh: 20: ./new_03_prepare_dataaugment.sh: suitable: not found
# steps/data/make_musan.sh --sampling-rate 16000 /home/qinyc/openSLR/SLR17_musan/musan data
# steps/data/make_musan.py --use-vocals true --sampling-rate 16000 /home/qinyc/openSLR/SLR17_musan/musan data/musan
# In music directory, processed 645 files; 0 had missing wav data
# In speech directory, processed 426 files; 0 had missing wav data
# In noise directory, processed 930 files; 0 had missing wav data
# utils/fix_data_dir.sh: file data/musan/utt2spk is not in sorted order or not unique, sorting it
# utils/fix_data_dir.sh: file data/musan/wav.scp is not in sorted order or not unique, sorting it
# fix_data_dir.sh: kept all 2001 utterances.
# fix_data_dir.sh: old files are kept in data/musan/.backup
# utils/subset_data_dir.sh: reducing #utt from 2001 to 645
# utils/subset_data_dir.sh: reducing #utt from 2001 to 426
# utils/subset_data_dir.sh: reducing #utt from 2001 to 930
# fix_data_dir.sh: kept all 645 utterances.
# fix_data_dir.sh: old files are kept in data/musan_music/.backup
# fix_data_dir.sh: kept all 426 utterances.
# fix_data_dir.sh: old files are kept in data/musan_speech/.backup
# fix_data_dir.sh: kept all 930 utterances.
# fix_data_dir.sh: old files are kept in data/musan_noise/.backup
# utils/data/get_reco2dur.sh: obtaining durations from recordings
# utils/data/get_reco2dur.sh: could not get recording lengths from sphere-file headers, using wav-to-duration
# utils/data/get_reco2dur.sh: computed data/musan_speech/reco2dur
# utils/data/get_reco2dur.sh: obtaining durations from recordings
# cat: write error: Broken pipe
# utils/data/get_reco2dur.sh: could not get recording lengths from sphere-file headers, using wav-to-duration
# utils/data/get_reco2dur.sh: computed data/musan_noise/reco2dur
# utils/data/get_reco2dur.sh: obtaining durations from recordings
# utils/data/get_reco2dur.sh: could not get recording lengths from sphere-file headers, using wav-to-duration
# utils/data/get_reco2dur.sh: computed data/musan_music/reco2dur
# utils/data/get_utt2dur.sh: segments file does not exist so getting durations from wave files
# utils/data/get_utt2dur.sh: could not get utterance lengths from sphere-file headers, using wav-to-duration
# utils/data/get_utt2dur.sh: computed data/musan_speech/utt2dur
# utils/data/get_utt2dur.sh: segments file does not exist so getting durations from wave files
# utils/data/get_utt2dur.sh: could not get utterance lengths from sphere-file headers, using wav-to-duration
# utils/data/get_utt2dur.sh: computed data/musan_noise/utt2dur
# utils/data/get_utt2dur.sh: segments file does not exist so getting durations from wave files
# utils/data/get_utt2dur.sh: could not get utterance lengths from sphere-file headers, using wav-to-duration
# utils/data/get_utt2dur.sh: computed data/musan_music/utt2dur
# steps/data/augment_data_dir.py:12: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import sys, random, argparse, os, imp
# steps/data/augment_data_dir.py --utt-suffix noise --fg-interval 1 --fg-snrs 15:10:5:0 --fg-noise-dir data/musan_noise data/train data/train_noise
# steps/data/augment_data_dir.py:12: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import sys, random, argparse, os, imp
# steps/data/augment_data_dir.py --utt-suffix music --bg-snrs 15:10:8:5 --num-bg-noises 1 --bg-noise-dir data/musan_music data/train data/train_music
# steps/data/augment_data_dir.py:12: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import sys, random, argparse, os, imp
# steps/data/augment_data_dir.py --utt-suffix babble --bg-snrs 20:17:15:13 --num-bg-noises 3:4:5:6:7 --bg-noise-dir data/musan_speech data/train data/train_babble
# utils/combine_data.sh data/train_aug data/train_reverb data/train_noise data/train_music data/train_babble
# utils/combine_data.sh: combined utt2uniq
# utils/combine_data.sh [info]: not combining segments as it does not exist
# utils/combine_data.sh: combined utt2spk
# utils/combine_data.sh [info]: not combining utt2lang as it does not exist
# utils/combine_data.sh [info]: **not combining utt2dur as it does not exist everywhere**
# utils/combine_data.sh [info]: **not combining utt2num_frames as it does not exist everywhere**
# utils/combine_data.sh [info]: **not combining reco2dur as it does not exist everywhere**
# utils/combine_data.sh [info]: not combining feats.scp as it does not exist
# utils/combine_data.sh: combined text
# utils/combine_data.sh [info]: not combining cmvn.scp as it does not exist
# utils/combine_data.sh: combined vad.scp
# utils/combine_data.sh [info]: not combining reco2file_and_channel as it does not exist
# utils/combine_data.sh: combined wav.scp
# utils/combine_data.sh [info]: not combining spk2gender as it does not exist
# fix_data_dir.sh: kept all 480392 utterances.
# fix_data_dir.sh: old files are kept in data/train_aug/.backup
# 耗时： 60.998231172561646

# %% [markdown]
# **第四步：** 将第三步中扩充的数据提取为MFCC表征
#
#     数据同样保存在mfcc这个文件中，日志文件存放在exp/make_mfcc

# %%
ss = time.time()

# !chmod +x new_04_extract_feature.sh
# !./new_04_extract_feature.sh

print("耗时：",time.time() - ss)
# Out:
# steps/make_mfcc.sh --mfcc-config conf/mfcc.conf --nj 20 --cmd run.pl --mem 10G data/train_aug exp/make_mfcc mfcc
# utils/validate_data_dir.sh: Successfully validated data-directory data/train_aug
# steps/make_mfcc.sh: [info]: no segments file exists: assuming wav.scp indexed by utterance.
# steps/make_mfcc.sh: Succeeded creating MFCC features for train_aug
# 耗时： 8234.177950143814

# %% [markdown]
# **第五步：** 过滤语音
#
#     ## 1. 将train_aug数据和train数据合并
#     ## 2. 该脚本应用CMVN并删除非语音帧。 会重新复制一份feature，确保磁盘空间。
#     ## 3. 删除静音帧后删除过短的功能。200帧
#     ## 4. 去除语音数量少于8个的说话人。

# %%
ss = time.time()

# !chmod +x new_05_filter_feature.sh
# !./new_05_filter_feature.sh

print("耗时：",time.time() - ss)
# Out:
# utils/combine_data.sh data/train_combined data/train_aug data/train
# utils/combine_data.sh: combined utt2uniq
# utils/combine_data.sh [info]: not combining segments as it does not exist
# utils/combine_data.sh: combined utt2spk
# utils/combine_data.sh [info]: not combining utt2lang as it does not exist
# utils/combine_data.sh: combined utt2dur
# utils/combine_data.sh: combined utt2num_frames
# utils/combine_data.sh [info]: **not combining reco2dur as it does not exist everywhere**
# utils/combine_data.sh: combined feats.scp
# utils/combine_data.sh: combined text
# utils/combine_data.sh [info]: not combining cmvn.scp as it does not exist
# utils/combine_data.sh: combined vad.scp
# utils/combine_data.sh [info]: not combining reco2file_and_channel as it does not exist
# utils/combine_data.sh: combined wav.scp
# utils/combine_data.sh [info]: not combining spk2gender as it does not exist
# fix_data_dir.sh: kept all 600490 utterances.
# fix_data_dir.sh: old files are kept in data/train_combined/.backup
# fix_data_dir.sh: kept all 600490 utterances.
# fix_data_dir.sh: old files are kept in data/train_combined/.backup
# local/nnet3/xvector/prepare_feats_for_egs.sh --nj 40 --cmd run.pl --mem 10G data/train_combined data/train_combined_no_sil exp/train_combined_no_sil
# local/nnet3/xvector/prepare_feats_for_egs.sh: Succeeded creating xvector features for train_combined
# fix_data_dir.sh: kept all 600490 utterances.
# fix_data_dir.sh: old files are kept in data/train_combined_no_sil/.backup
# fix_data_dir.sh: kept all 590655 utterances.
# fix_data_dir.sh: old files are kept in data/train_combined_no_sil/.backup
# fix_data_dir.sh: kept all 590655 utterances.
# fix_data_dir.sh: old files are kept in data/train_combined_no_sil/.backup
# 耗时： 149.38492822647095

# %% [markdown]
# **第六步：** 建立训练模型
#
#     1.构建模型的结构
#     2.训练模型
#
#     生成了最终的x-vector 模型，final.raw

# %%
# !/home/amax/Codes/softwares/kaldi-trunk/src/nnet3bin/nnet3-init ./exp/xvector_nnet_1a/nnet.config ./exp/xvector_nnet_1a/0.raw
# Out:
# /home/amax/Codes/softwares/kaldi-trunk/src/nnet3bin/nnet3-init ./exp/xvector_nnet_1a/nnet.config ./exp/xvector_nnet_1a/0.raw
# LOG (nnet3-init[5.5.480~1-09abd]:main():nnet3-init.cc:80) Initialized raw neural net and wrote it to ./exp/xvector_nnet_1a/0.raw

# %%
ss = time.time()

# !chmod +x new_06_train_x-vector.sh
# !bash new_06_train_x-vector.sh --stage 0 --train-stage 0 --data data/train_combined_no_sil --nnet-dir exp/xvector_nnet_1a --egs-dir exp/xvector_nnet_1a/egs

print("耗时：",time.time() - ss)

## 单线程 GPU加速， 占用5205MiB的显存
# Out:
# new_06_train_x-vector.sh: Getting neural network training egs
# sid/nnet3/xvector/get_egs.sh --cmd run.pl --mem 10G --nj 8 --stage 0 --frames-per-iter 1000000000 --frames-per-iter-diagnostic 100000 --min-frames-per-chunk 100 --max-frames-per-chunk 200 --num-diagnostic-archives 3 --num-repeats 35 data/train_combined_no_sil exp/xvector_nnet_1a/egs
# feat-to-dim scp:data/train_combined_no_sil/feats.scp -
# sid/nnet3/xvector/get_egs.sh: Preparing train and validation lists
# sid/nnet3/xvector/get_egs.sh: Producing 9 archives for training
# 1
# sid/nnet3/xvector/get_egs.sh: Allocating training examples
# sid/nnet3/xvector/get_egs.sh: Allocating training subset examples
# sid/nnet3/xvector/get_egs.sh: Allocating validation examples
# 2
# sid/nnet3/xvector/get_egs.sh: Generating training examples on disk
# sid/nnet3/xvector/get_egs.sh: Generating training subset examples on disk
# sid/nnet3/xvector/get_egs.sh: Generating validation examples on disk
# 3
# sid/nnet3/xvector/get_egs.sh: Shuffling order of archives on disk
# sid/nnet3/xvector/get_egs.sh: Finished preparing training examples
# new_06_train_x-vector.sh: creating neural net configs using the xconfig parser
# steps/nnet3/xconfig_to_configs.py --xconfig-file exp/xvector_nnet_1a/configs/network.xconfig --config-dir exp/xvector_nnet_1a/configs/
# nnet3-init exp/xvector_nnet_1a/configs//ref.config exp/xvector_nnet_1a/configs//ref.raw
# LOG (nnet3-init[5.5.480~1-09abd]:main():nnet3-init.cc:80) Initialized raw neural net and wrote it to exp/xvector_nnet_1a/configs//ref.raw
# nnet3-info exp/xvector_nnet_1a/configs//ref.raw
# nnet3-init exp/xvector_nnet_1a/configs//ref.config exp/xvector_nnet_1a/configs//ref.raw
# LOG (nnet3-init[5.5.480~1-09abd]:main():nnet3-init.cc:80) Initialized raw neural net and wrote it to exp/xvector_nnet_1a/configs//ref.raw
# nnet3-info exp/xvector_nnet_1a/configs//ref.raw
# 2020-11-04 00:09:59,047 [steps/nnet3/train_raw_dnn.py:35 - <module> - INFO ] Starting raw DNN trainer (train_raw_dnn.py)
# steps/nnet3/train_raw_dnn.py --stage=0 --cmd=run.pl --mem 10G --trainer.optimization.proportional-shrink 10 --trainer.optimization.momentum=0.5 --trainer.optimization.num-jobs-initial=1 --trainer.optimization.num-jobs-final=1 --trainer.optimization.initial-effective-lrate=0.001 --trainer.optimization.final-effective-lrate=0.0001 --trainer.optimization.minibatch-size=64 --trainer.srand=123 --trainer.max-param-change=2 --trainer.num-epochs=80 --trainer.dropout-schedule=0,0@0.20,0.1@0.50,0 --trainer.shuffle-buffer-size=1000 --egs.frames-per-eg=1 --egs.dir=exp/xvector_nnet_1a/egs --cleanup.remove-egs false --cleanup.preserve-model-interval=10 --use-gpu=true --dir=exp/xvector_nnet_1a
# ['steps/nnet3/train_raw_dnn.py', '--stage=0', '--cmd=run.pl --mem 10G', '--trainer.optimization.proportional-shrink', '10', '--trainer.optimization.momentum=0.5', '--trainer.optimization.num-jobs-initial=1', '--trainer.optimization.num-jobs-final=1', '--trainer.optimization.initial-effective-lrate=0.001', '--trainer.optimization.final-effective-lrate=0.0001', '--trainer.optimization.minibatch-size=64', '--trainer.srand=123', '--trainer.max-param-change=2', '--trainer.num-epochs=80', '--trainer.dropout-schedule=0,0@0.20,0.1@0.50,0', '--trainer.shuffle-buffer-size=1000', '--egs.frames-per-eg=1', '--egs.dir=exp/xvector_nnet_1a/egs', '--cleanup.remove-egs', 'false', '--cleanup.preserve-model-interval=10', '--use-gpu=true', '--dir=exp/xvector_nnet_1a']
# 2020-11-04 00:09:59,052 [steps/nnet3/train_raw_dnn.py:196 - train - INFO ] Arguments for the experiment
# {'backstitch_training_interval': 1,
#  'backstitch_training_scale': 0.0,
#  'cleanup': True,
#  'cmvn_opts': None,
#  'combine_sum_to_one_penalty': 0.0,
#  'command': 'run.pl --mem 10G',
#  'compute_average_posteriors': False,
#  'compute_per_dim_accuracy': False,
#  'dir': 'exp/xvector_nnet_1a',
#  'do_final_combination': True,
#  'dropout_schedule': '0,0@0.20,0.1@0.50,0',
#  'egs_command': None,
#  'egs_dir': 'exp/xvector_nnet_1a/egs',
#  'egs_opts': None,
#  'egs_stage': 0,
#  'email': None,
#  'exit_stage': None,
#  'feat_dir': None,
#  'final_effective_lrate': 0.0001,
#  'frames_per_eg': 1,
#  'image_augmentation_opts': None,
#  'initial_effective_lrate': 0.001,
#  'input_model': None,
#  'max_lda_jobs': 10,
#  'max_models_combine': 20,
#  'max_objective_evaluations': 30,
#  'max_param_change': 2.0,
#  'minibatch_size': '64',
#  'momentum': 0.5,
#  'nj': 4,
#  'num_epochs': 80.0,
#  'num_jobs_compute_prior': 10,
#  'num_jobs_final': 1,
#  'num_jobs_initial': 1,
#  'num_jobs_step': 1,
#  'online_ivector_dir': None,
#  'preserve_model_interval': 10,
#  'presoftmax_prior_scale_power': -0.25,
#  'prior_subset_size': 20000,
#  'proportional_shrink': 10.0,
#  'rand_prune': 4.0,
#  'remove_egs': False,
#  'reporting_interval': 0.1,
#  'samples_per_iter': 400000,
#  'shuffle_buffer_size': 1000,
#  'srand': 123,
#  'stage': 0,
#  'targets_scp': None,
#  'train_opts': [],
#  'use_dense_targets': True,
#  'use_gpu': 'yes'}
# 2020-11-04 00:09:59,053 [steps/nnet3/train_raw_dnn.py:354 - train - INFO ] Training will run for 80.0 epochs = 720 iterations
# 2020-11-04 00:09:59,053 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 0/719   Jobs: 1   Epoch: 0.00/80.0 (0.0% complete)   lr: 0.001000   shrink: 0.99000
# 2020-11-04 00:10:07,134 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 1/719   Jobs: 1   Epoch: 0.11/80.0 (0.1% complete)   lr: 0.000997   shrink: 0.99003
# 2020-11-04 00:10:15,384 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 2/719   Jobs: 1   Epoch: 0.22/80.0 (0.3% complete)   lr: 0.000994   shrink: 0.99006
# 2020-11-04 00:10:22,388 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 3/719   Jobs: 1   Epoch: 0.33/80.0 (0.4% complete)   lr: 0.000990   shrink: 0.99010
# 2020-11-04 00:10:29,488 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 4/719   Jobs: 1   Epoch: 0.44/80.0 (0.6% complete)   lr: 0.000987   shrink: 0.99013
# 2020-11-04 00:10:38,452 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 5/719   Jobs: 1   Epoch: 0.56/80.0 (0.7% complete)   lr: 0.000984   shrink: 0.99016
# 2020-11-04 00:10:46,551 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 6/719   Jobs: 1   Epoch: 0.67/80.0 (0.8% complete)   lr: 0.000981   shrink: 0.99019
# 2020-11-04 00:10:57,493 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 7/719   Jobs: 1   Epoch: 0.78/80.0 (1.0% complete)   lr: 0.000978   shrink: 0.99022
# 2020-11-04 00:11:06,975 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 8/719   Jobs: 1   Epoch: 0.89/80.0 (1.1% complete)   lr: 0.000975   shrink: 0.99025
# 2020-11-04 00:11:18,007 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 9/719   Jobs: 1   Epoch: 1.00/80.0 (1.2% complete)   lr: 0.000972   shrink: 0.99028
# 2020-11-04 00:11:24,823 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 10/719   Jobs: 1   Epoch: 1.11/80.0 (1.4% complete)   lr: 0.000969   shrink: 0.99031
# 2020-11-04 00:11:32,637 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 11/719   Jobs: 1   Epoch: 1.22/80.0 (1.5% complete)   lr: 0.000965   shrink: 0.99035
# 2020-11-04 00:11:39,200 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 12/719   Jobs: 1   Epoch: 1.33/80.0 (1.7% complete)   lr: 0.000962   shrink: 0.99038
# 2020-11-04 00:11:45,760 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 13/719   Jobs: 1   Epoch: 1.44/80.0 (1.8% complete)   lr: 0.000959   shrink: 0.99041
# 2020-11-04 00:11:54,281 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 14/719   Jobs: 1   Epoch: 1.56/80.0 (1.9% complete)   lr: 0.000956   shrink: 0.99044
# 2020-11-04 00:12:01,808 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 15/719   Jobs: 1   Epoch: 1.67/80.0 (2.1% complete)   lr: 0.000953   shrink: 0.99047
# 2020-11-04 00:12:12,303 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 16/719   Jobs: 1   Epoch: 1.78/80.0 (2.2% complete)   lr: 0.000950   shrink: 0.99050
# 2020-11-04 00:12:21,211 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 17/719   Jobs: 1   Epoch: 1.89/80.0 (2.4% complete)   lr: 0.000947   shrink: 0.99053
# 2020-11-04 00:12:31,690 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 18/719   Jobs: 1   Epoch: 2.00/80.0 (2.5% complete)   lr: 0.000944   shrink: 0.99056
# 2020-11-04 00:12:38,501 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 19/719   Jobs: 1   Epoch: 2.11/80.0 (2.6% complete)   lr: 0.000941   shrink: 0.99059
# 2020-11-04 00:12:46,322 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 20/719   Jobs: 1   Epoch: 2.22/80.0 (2.8% complete)   lr: 0.000938   shrink: 0.99062
# 2020-11-04 00:12:53,632 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 21/719   Jobs: 1   Epoch: 2.33/80.0 (2.9% complete)   lr: 0.000935   shrink: 0.99065
# 2020-11-04 00:13:00,216 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 22/719   Jobs: 1   Epoch: 2.44/80.0 (3.1% complete)   lr: 0.000932   shrink: 0.99068
# 2020-11-04 00:13:08,676 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 23/719   Jobs: 1   Epoch: 2.56/80.0 (3.2% complete)   lr: 0.000929   shrink: 0.99071
# 2020-11-04 00:13:16,200 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 24/719   Jobs: 1   Epoch: 2.67/80.0 (3.3% complete)   lr: 0.000926   shrink: 0.99074
# 2020-11-04 00:13:26,654 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 25/719   Jobs: 1   Epoch: 2.78/80.0 (3.5% complete)   lr: 0.000923   shrink: 0.99077
# 2020-11-04 00:13:35,581 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 26/719   Jobs: 1   Epoch: 2.89/80.0 (3.6% complete)   lr: 0.000920   shrink: 0.99080
# 2020-11-04 00:13:46,069 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 27/719   Jobs: 1   Epoch: 3.00/80.0 (3.8% complete)   lr: 0.000917   shrink: 0.99083
# 2020-11-04 00:13:52,874 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 28/719   Jobs: 1   Epoch: 3.11/80.0 (3.9% complete)   lr: 0.000914   shrink: 0.99086
# 2020-11-04 00:14:00,660 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 29/719   Jobs: 1   Epoch: 3.22/80.0 (4.0% complete)   lr: 0.000911   shrink: 0.99089
# 2020-11-04 00:14:07,195 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 30/719   Jobs: 1   Epoch: 3.33/80.0 (4.2% complete)   lr: 0.000909   shrink: 0.99091
# 2020-11-04 00:14:13,847 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 31/719   Jobs: 1   Epoch: 3.44/80.0 (4.3% complete)   lr: 0.000906   shrink: 0.99094
# 2020-11-04 00:14:22,361 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 32/719   Jobs: 1   Epoch: 3.56/80.0 (4.4% complete)   lr: 0.000903   shrink: 0.99097
# 2020-11-04 00:14:29,865 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 33/719   Jobs: 1   Epoch: 3.67/80.0 (4.6% complete)   lr: 0.000900   shrink: 0.99100
# 2020-11-04 00:14:40,639 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 34/719   Jobs: 1   Epoch: 3.78/80.0 (4.7% complete)   lr: 0.000897   shrink: 0.99103
# 2020-11-04 00:14:49,531 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 35/719   Jobs: 1   Epoch: 3.89/80.0 (4.9% complete)   lr: 0.000894   shrink: 0.99106
# 2020-11-04 00:15:00,015 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 36/719   Jobs: 1   Epoch: 4.00/80.0 (5.0% complete)   lr: 0.000891   shrink: 0.99109
# 2020-11-04 00:15:06,858 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 37/719   Jobs: 1   Epoch: 4.11/80.0 (5.1% complete)   lr: 0.000888   shrink: 0.99112
# 2020-11-04 00:15:14,716 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 38/719   Jobs: 1   Epoch: 4.22/80.0 (5.3% complete)   lr: 0.000886   shrink: 0.99114
# 2020-11-04 00:15:21,247 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 39/719   Jobs: 1   Epoch: 4.33/80.0 (5.4% complete)   lr: 0.000883   shrink: 0.99117
# 2020-11-04 00:15:27,878 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 40/719   Jobs: 1   Epoch: 4.44/80.0 (5.6% complete)   lr: 0.000880   shrink: 0.99120
# 2020-11-04 00:15:37,060 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 41/719   Jobs: 1   Epoch: 4.56/80.0 (5.7% complete)   lr: 0.000877   shrink: 0.99123
# 2020-11-04 00:15:44,600 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 42/719   Jobs: 1   Epoch: 4.67/80.0 (5.8% complete)   lr: 0.000874   shrink: 0.99126
# 2020-11-04 00:15:55,109 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 43/719   Jobs: 1   Epoch: 4.78/80.0 (6.0% complete)   lr: 0.000872   shrink: 0.99128
# 2020-11-04 00:16:04,093 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 44/719   Jobs: 1   Epoch: 4.89/80.0 (6.1% complete)   lr: 0.000869   shrink: 0.99131
# 2020-11-04 00:16:14,604 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 45/719   Jobs: 1   Epoch: 5.00/80.0 (6.2% complete)   lr: 0.000866   shrink: 0.99134
# 2020-11-04 00:16:21,381 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 46/719   Jobs: 1   Epoch: 5.11/80.0 (6.4% complete)   lr: 0.000863   shrink: 0.99137
# 2020-11-04 00:16:29,236 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 47/719   Jobs: 1   Epoch: 5.22/80.0 (6.5% complete)   lr: 0.000860   shrink: 0.99140
# 2020-11-04 00:16:35,788 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 48/719   Jobs: 1   Epoch: 5.33/80.0 (6.7% complete)   lr: 0.000858   shrink: 0.99142
# 2020-11-04 00:16:42,369 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 49/719   Jobs: 1   Epoch: 5.44/80.0 (6.8% complete)   lr: 0.000855   shrink: 0.99145
# 2020-11-04 00:16:50,875 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 50/719   Jobs: 1   Epoch: 5.56/80.0 (6.9% complete)   lr: 0.000852   shrink: 0.99148
# 2020-11-04 00:16:58,434 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 51/719   Jobs: 1   Epoch: 5.67/80.0 (7.1% complete)   lr: 0.000850   shrink: 0.99150
# 2020-11-04 00:17:08,947 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 52/719   Jobs: 1   Epoch: 5.78/80.0 (7.2% complete)   lr: 0.000847   shrink: 0.99153
# 2020-11-04 00:17:17,838 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 53/719   Jobs: 1   Epoch: 5.89/80.0 (7.4% complete)   lr: 0.000844   shrink: 0.99156
# 2020-11-04 00:17:28,339 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 54/719   Jobs: 1   Epoch: 6.00/80.0 (7.5% complete)   lr: 0.000841   shrink: 0.99159
# 2020-11-04 00:17:35,097 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 55/719   Jobs: 1   Epoch: 6.11/80.0 (7.6% complete)   lr: 0.000839   shrink: 0.99161
# 2020-11-04 00:17:42,924 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 56/719   Jobs: 1   Epoch: 6.22/80.0 (7.8% complete)   lr: 0.000836   shrink: 0.99164
# 2020-11-04 00:17:49,486 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 57/719   Jobs: 1   Epoch: 6.33/80.0 (7.9% complete)   lr: 0.000833   shrink: 0.99167
# 2020-11-04 00:17:56,096 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 58/719   Jobs: 1   Epoch: 6.44/80.0 (8.1% complete)   lr: 0.000831   shrink: 0.99169
# 2020-11-04 00:18:04,602 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 59/719   Jobs: 1   Epoch: 6.56/80.0 (8.2% complete)   lr: 0.000828   shrink: 0.99172
# 2020-11-04 00:18:12,396 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 60/719   Jobs: 1   Epoch: 6.67/80.0 (8.3% complete)   lr: 0.000825   shrink: 0.99175
# 2020-11-04 00:18:23,567 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 61/719   Jobs: 1   Epoch: 6.78/80.0 (8.5% complete)   lr: 0.000823   shrink: 0.99177
# 2020-11-04 00:18:32,475 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 62/719   Jobs: 1   Epoch: 6.89/80.0 (8.6% complete)   lr: 0.000820   shrink: 0.99180
# 2020-11-04 00:18:42,955 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 63/719   Jobs: 1   Epoch: 7.00/80.0 (8.8% complete)   lr: 0.000818   shrink: 0.99182
# 2020-11-04 00:18:49,733 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 64/719   Jobs: 1   Epoch: 7.11/80.0 (8.9% complete)   lr: 0.000815   shrink: 0.99185
# 2020-11-04 00:18:57,512 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 65/719   Jobs: 1   Epoch: 7.22/80.0 (9.0% complete)   lr: 0.000812   shrink: 0.99188
# 2020-11-04 00:19:04,059 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 66/719   Jobs: 1   Epoch: 7.33/80.0 (9.2% complete)   lr: 0.000810   shrink: 0.99190
# 2020-11-04 00:19:10,697 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 67/719   Jobs: 1   Epoch: 7.44/80.0 (9.3% complete)   lr: 0.000807   shrink: 0.99193
# 2020-11-04 00:19:19,234 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 68/719   Jobs: 1   Epoch: 7.56/80.0 (9.4% complete)   lr: 0.000805   shrink: 0.99195
# 2020-11-04 00:19:26,752 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 69/719   Jobs: 1   Epoch: 7.67/80.0 (9.6% complete)   lr: 0.000802   shrink: 0.99198
# 2020-11-04 00:19:37,248 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 70/719   Jobs: 1   Epoch: 7.78/80.0 (9.7% complete)   lr: 0.000799   shrink: 0.99201
# 2020-11-04 00:19:46,191 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 71/719   Jobs: 1   Epoch: 7.89/80.0 (9.9% complete)   lr: 0.000797   shrink: 0.99203
# 2020-11-04 00:19:56,658 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 72/719   Jobs: 1   Epoch: 8.00/80.0 (10.0% complete)   lr: 0.000794   shrink: 0.99206
# 2020-11-04 00:20:03,452 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 73/719   Jobs: 1   Epoch: 8.11/80.0 (10.1% complete)   lr: 0.000792   shrink: 0.99208
# 2020-11-04 00:20:11,263 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 74/719   Jobs: 1   Epoch: 8.22/80.0 (10.3% complete)   lr: 0.000789   shrink: 0.99211
# 2020-11-04 00:20:17,813 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 75/719   Jobs: 1   Epoch: 8.33/80.0 (10.4% complete)   lr: 0.000787   shrink: 0.99213
# 2020-11-04 00:20:24,407 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 76/719   Jobs: 1   Epoch: 8.44/80.0 (10.6% complete)   lr: 0.000784   shrink: 0.99216
# 2020-11-04 00:20:32,867 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 77/719   Jobs: 1   Epoch: 8.56/80.0 (10.7% complete)   lr: 0.000782   shrink: 0.99218
# 2020-11-04 00:20:40,351 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 78/719   Jobs: 1   Epoch: 8.67/80.0 (10.8% complete)   lr: 0.000779   shrink: 0.99221
# 2020-11-04 00:20:50,786 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 79/719   Jobs: 1   Epoch: 8.78/80.0 (11.0% complete)   lr: 0.000777   shrink: 0.99223
# 2020-11-04 00:20:59,667 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 80/719   Jobs: 1   Epoch: 8.89/80.0 (11.1% complete)   lr: 0.000774   shrink: 0.99226
# 2020-11-04 00:21:10,779 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 81/719   Jobs: 1   Epoch: 9.00/80.0 (11.2% complete)   lr: 0.000772   shrink: 0.99228
# 2020-11-04 00:21:17,547 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 82/719   Jobs: 1   Epoch: 9.11/80.0 (11.4% complete)   lr: 0.000769   shrink: 0.99231
# 2020-11-04 00:21:25,375 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 83/719   Jobs: 1   Epoch: 9.22/80.0 (11.5% complete)   lr: 0.000767   shrink: 0.99233
# 2020-11-04 00:21:31,874 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 84/719   Jobs: 1   Epoch: 9.33/80.0 (11.7% complete)   lr: 0.000764   shrink: 0.99236
# 2020-11-04 00:21:38,524 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 85/719   Jobs: 1   Epoch: 9.44/80.0 (11.8% complete)   lr: 0.000762   shrink: 0.99238
# 2020-11-04 00:21:47,019 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 86/719   Jobs: 1   Epoch: 9.56/80.0 (11.9% complete)   lr: 0.000760   shrink: 0.99240
# 2020-11-04 00:21:54,495 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 87/719   Jobs: 1   Epoch: 9.67/80.0 (12.1% complete)   lr: 0.000757   shrink: 0.99243
# 2020-11-04 00:22:04,904 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 88/719   Jobs: 1   Epoch: 9.78/80.0 (12.2% complete)   lr: 0.000755   shrink: 0.99245
# 2020-11-04 00:22:13,795 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 89/719   Jobs: 1   Epoch: 9.89/80.0 (12.4% complete)   lr: 0.000752   shrink: 0.99248
# 2020-11-04 00:22:24,205 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 90/719   Jobs: 1   Epoch: 10.00/80.0 (12.5% complete)   lr: 0.000750   shrink: 0.99250
# 2020-11-04 00:22:31,048 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 91/719   Jobs: 1   Epoch: 10.11/80.0 (12.6% complete)   lr: 0.000747   shrink: 0.99253
# 2020-11-04 00:22:38,856 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 92/719   Jobs: 1   Epoch: 10.22/80.0 (12.8% complete)   lr: 0.000745   shrink: 0.99255
# 2020-11-04 00:22:45,396 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 93/719   Jobs: 1   Epoch: 10.33/80.0 (12.9% complete)   lr: 0.000743   shrink: 0.99257
# 2020-11-04 00:22:52,012 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 94/719   Jobs: 1   Epoch: 10.44/80.0 (13.1% complete)   lr: 0.000740   shrink: 0.99260
# 2020-11-04 00:23:00,506 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 95/719   Jobs: 1   Epoch: 10.56/80.0 (13.2% complete)   lr: 0.000738   shrink: 0.99262
# 2020-11-04 00:23:08,027 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 96/719   Jobs: 1   Epoch: 10.67/80.0 (13.3% complete)   lr: 0.000736   shrink: 0.99264
# 2020-11-04 00:23:18,489 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 97/719   Jobs: 1   Epoch: 10.78/80.0 (13.5% complete)   lr: 0.000733   shrink: 0.99267
# 2020-11-04 00:23:27,404 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 98/719   Jobs: 1   Epoch: 10.89/80.0 (13.6% complete)   lr: 0.000731   shrink: 0.99269
# 2020-11-04 00:23:37,827 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 99/719   Jobs: 1   Epoch: 11.00/80.0 (13.8% complete)   lr: 0.000729   shrink: 0.99271
# 2020-11-04 00:23:44,607 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 100/719   Jobs: 1   Epoch: 11.11/80.0 (13.9% complete)   lr: 0.000726   shrink: 0.99274
# 2020-11-04 00:23:53,136 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 101/719   Jobs: 1   Epoch: 11.22/80.0 (14.0% complete)   lr: 0.000724   shrink: 0.99276
# 2020-11-04 00:23:59,715 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 102/719   Jobs: 1   Epoch: 11.33/80.0 (14.2% complete)   lr: 0.000722   shrink: 0.99278
# 2020-11-04 00:24:06,316 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 103/719   Jobs: 1   Epoch: 11.44/80.0 (14.3% complete)   lr: 0.000719   shrink: 0.99281
# 2020-11-04 00:24:14,758 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 104/719   Jobs: 1   Epoch: 11.56/80.0 (14.4% complete)   lr: 0.000717   shrink: 0.99283
# 2020-11-04 00:24:22,345 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 105/719   Jobs: 1   Epoch: 11.67/80.0 (14.6% complete)   lr: 0.000715   shrink: 0.99285
# 2020-11-04 00:24:32,790 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 106/719   Jobs: 1   Epoch: 11.78/80.0 (14.7% complete)   lr: 0.000712   shrink: 0.99288
# 2020-11-04 00:24:41,710 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 107/719   Jobs: 1   Epoch: 11.89/80.0 (14.9% complete)   lr: 0.000710   shrink: 0.99290
# 2020-11-04 00:24:52,208 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 108/719   Jobs: 1   Epoch: 12.00/80.0 (15.0% complete)   lr: 0.000708   shrink: 0.99292
# 2020-11-04 00:24:59,009 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 109/719   Jobs: 1   Epoch: 12.11/80.0 (15.1% complete)   lr: 0.000706   shrink: 0.99294
# 2020-11-04 00:25:06,868 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 110/719   Jobs: 1   Epoch: 12.22/80.0 (15.3% complete)   lr: 0.000703   shrink: 0.99297
# 2020-11-04 00:25:13,406 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 111/719   Jobs: 1   Epoch: 12.33/80.0 (15.4% complete)   lr: 0.000701   shrink: 0.99299
# 2020-11-04 00:25:20,059 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 112/719   Jobs: 1   Epoch: 12.44/80.0 (15.6% complete)   lr: 0.000699   shrink: 0.99301
# 2020-11-04 00:25:28,558 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 113/719   Jobs: 1   Epoch: 12.56/80.0 (15.7% complete)   lr: 0.000697   shrink: 0.99303
# 2020-11-04 00:25:36,094 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 114/719   Jobs: 1   Epoch: 12.67/80.0 (15.8% complete)   lr: 0.000694   shrink: 0.99306
# 2020-11-04 00:25:46,606 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 115/719   Jobs: 1   Epoch: 12.78/80.0 (16.0% complete)   lr: 0.000692   shrink: 0.99308
# 2020-11-04 00:25:55,537 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 116/719   Jobs: 1   Epoch: 12.89/80.0 (16.1% complete)   lr: 0.000690   shrink: 0.99310
# 2020-11-04 00:26:06,015 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 117/719   Jobs: 1   Epoch: 13.00/80.0 (16.2% complete)   lr: 0.000688   shrink: 0.99312
# 2020-11-04 00:26:12,864 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 118/719   Jobs: 1   Epoch: 13.11/80.0 (16.4% complete)   lr: 0.000686   shrink: 0.99314
# 2020-11-04 00:26:20,748 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 119/719   Jobs: 1   Epoch: 13.22/80.0 (16.5% complete)   lr: 0.000683   shrink: 0.99317
# 2020-11-04 00:26:27,306 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 120/719   Jobs: 1   Epoch: 13.33/80.0 (16.7% complete)   lr: 0.000681   shrink: 0.99319
# 2020-11-04 00:26:34,615 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 121/719   Jobs: 1   Epoch: 13.44/80.0 (16.8% complete)   lr: 0.000679   shrink: 0.99321
# 2020-11-04 00:26:43,144 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 122/719   Jobs: 1   Epoch: 13.56/80.0 (16.9% complete)   lr: 0.000677   shrink: 0.99323
# 2020-11-04 00:26:50,673 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 123/719   Jobs: 1   Epoch: 13.67/80.0 (17.1% complete)   lr: 0.000675   shrink: 0.99325
# 2020-11-04 00:27:01,126 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 124/719   Jobs: 1   Epoch: 13.78/80.0 (17.2% complete)   lr: 0.000673   shrink: 0.99327
# 2020-11-04 00:27:10,006 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 125/719   Jobs: 1   Epoch: 13.89/80.0 (17.4% complete)   lr: 0.000670   shrink: 0.99330
# 2020-11-04 00:27:20,468 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 126/719   Jobs: 1   Epoch: 14.00/80.0 (17.5% complete)   lr: 0.000668   shrink: 0.99332
# 2020-11-04 00:27:27,259 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 127/719   Jobs: 1   Epoch: 14.11/80.0 (17.6% complete)   lr: 0.000666   shrink: 0.99334
# 2020-11-04 00:27:35,034 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 128/719   Jobs: 1   Epoch: 14.22/80.0 (17.8% complete)   lr: 0.000664   shrink: 0.99336
# 2020-11-04 00:27:41,653 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 129/719   Jobs: 1   Epoch: 14.33/80.0 (17.9% complete)   lr: 0.000662   shrink: 0.99338
# 2020-11-04 00:27:48,312 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 130/719   Jobs: 1   Epoch: 14.44/80.0 (18.1% complete)   lr: 0.000660   shrink: 0.99340
# 2020-11-04 00:27:56,808 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 131/719   Jobs: 1   Epoch: 14.56/80.0 (18.2% complete)   lr: 0.000658   shrink: 0.99342
# 2020-11-04 00:28:04,348 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 132/719   Jobs: 1   Epoch: 14.67/80.0 (18.3% complete)   lr: 0.000656   shrink: 0.99344
# 2020-11-04 00:28:14,827 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 133/719   Jobs: 1   Epoch: 14.78/80.0 (18.5% complete)   lr: 0.000654   shrink: 0.99346
# 2020-11-04 00:28:23,701 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 134/719   Jobs: 1   Epoch: 14.89/80.0 (18.6% complete)   lr: 0.000651   shrink: 0.99349
# 2020-11-04 00:28:34,115 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 135/719   Jobs: 1   Epoch: 15.00/80.0 (18.8% complete)   lr: 0.000649   shrink: 0.99351
# 2020-11-04 00:28:40,910 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 136/719   Jobs: 1   Epoch: 15.11/80.0 (18.9% complete)   lr: 0.000647   shrink: 0.99353
# 2020-11-04 00:28:48,838 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 137/719   Jobs: 1   Epoch: 15.22/80.0 (19.0% complete)   lr: 0.000645   shrink: 0.99355
# 2020-11-04 00:28:55,429 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 138/719   Jobs: 1   Epoch: 15.33/80.0 (19.2% complete)   lr: 0.000643   shrink: 0.99357
# 2020-11-04 00:29:02,035 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 139/719   Jobs: 1   Epoch: 15.44/80.0 (19.3% complete)   lr: 0.000641   shrink: 0.99359
# 2020-11-04 00:29:10,908 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 140/719   Jobs: 1   Epoch: 15.56/80.0 (19.4% complete)   lr: 0.000639   shrink: 0.99361
# 2020-11-04 00:29:19,100 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 141/719   Jobs: 1   Epoch: 15.67/80.0 (19.6% complete)   lr: 0.000637   shrink: 0.99363
# 2020-11-04 00:29:29,575 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 142/719   Jobs: 1   Epoch: 15.78/80.0 (19.7% complete)   lr: 0.000635   shrink: 0.99365
# 2020-11-04 00:29:38,472 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 143/719   Jobs: 1   Epoch: 15.89/80.0 (19.9% complete)   lr: 0.000633   shrink: 0.99367
# 2020-11-04 00:29:48,960 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 144/719   Jobs: 1   Epoch: 16.00/80.0 (20.0% complete)   lr: 0.000631   shrink: 0.99369
# 2020-11-04 00:29:55,788 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 145/719   Jobs: 1   Epoch: 16.11/80.0 (20.1% complete)   lr: 0.000629   shrink: 0.99371
# 2020-11-04 00:30:03,627 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 146/719   Jobs: 1   Epoch: 16.22/80.0 (20.3% complete)   lr: 0.000627   shrink: 0.99373
# 2020-11-04 00:30:10,250 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 147/719   Jobs: 1   Epoch: 16.33/80.0 (20.4% complete)   lr: 0.000625   shrink: 0.99375
# 2020-11-04 00:30:16,867 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 148/719   Jobs: 1   Epoch: 16.44/80.0 (20.6% complete)   lr: 0.000623   shrink: 0.99377
# 2020-11-04 00:30:25,409 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 149/719   Jobs: 1   Epoch: 16.56/80.0 (20.7% complete)   lr: 0.000621   shrink: 0.99379
# 2020-11-04 00:30:32,971 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 150/719   Jobs: 1   Epoch: 16.67/80.0 (20.8% complete)   lr: 0.000619   shrink: 0.99381
# 2020-11-04 00:30:43,486 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 151/719   Jobs: 1   Epoch: 16.78/80.0 (21.0% complete)   lr: 0.000617   shrink: 0.99383
# 2020-11-04 00:30:52,384 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 152/719   Jobs: 1   Epoch: 16.89/80.0 (21.1% complete)   lr: 0.000615   shrink: 0.99385
# 2020-11-04 00:31:02,875 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 153/719   Jobs: 1   Epoch: 17.00/80.0 (21.2% complete)   lr: 0.000613   shrink: 0.99387
# 2020-11-04 00:31:09,687 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 154/719   Jobs: 1   Epoch: 17.11/80.0 (21.4% complete)   lr: 0.000611   shrink: 0.99389
# 2020-11-04 00:31:17,558 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 155/719   Jobs: 1   Epoch: 17.22/80.0 (21.5% complete)   lr: 0.000609   shrink: 0.99391
# 2020-11-04 00:31:24,346 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 156/719   Jobs: 1   Epoch: 17.33/80.0 (21.7% complete)   lr: 0.000607   shrink: 0.99393
# 2020-11-04 00:31:31,028 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 157/719   Jobs: 1   Epoch: 17.44/80.0 (21.8% complete)   lr: 0.000605   shrink: 0.99395
# 2020-11-04 00:31:39,546 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 158/719   Jobs: 1   Epoch: 17.56/80.0 (21.9% complete)   lr: 0.000603   shrink: 0.99397
# 2020-11-04 00:31:47,082 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 159/719   Jobs: 1   Epoch: 17.67/80.0 (22.1% complete)   lr: 0.000601   shrink: 0.99399
# 2020-11-04 00:31:57,601 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 160/719   Jobs: 1   Epoch: 17.78/80.0 (22.2% complete)   lr: 0.000599   shrink: 0.99401
# 2020-11-04 00:32:07,268 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 161/719   Jobs: 1   Epoch: 17.89/80.0 (22.4% complete)   lr: 0.000598   shrink: 0.99402
# 2020-11-04 00:32:17,727 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 162/719   Jobs: 1   Epoch: 18.00/80.0 (22.5% complete)   lr: 0.000596   shrink: 0.99404
# 2020-11-04 00:32:24,535 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 163/719   Jobs: 1   Epoch: 18.11/80.0 (22.6% complete)   lr: 0.000594   shrink: 0.99406
# 2020-11-04 00:32:32,319 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 164/719   Jobs: 1   Epoch: 18.22/80.0 (22.8% complete)   lr: 0.000592   shrink: 0.99408
# 2020-11-04 00:32:38,848 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 165/719   Jobs: 1   Epoch: 18.33/80.0 (22.9% complete)   lr: 0.000590   shrink: 0.99410
# 2020-11-04 00:32:45,499 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 166/719   Jobs: 1   Epoch: 18.44/80.0 (23.1% complete)   lr: 0.000588   shrink: 0.99412
# 2020-11-04 00:32:53,956 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 167/719   Jobs: 1   Epoch: 18.56/80.0 (23.2% complete)   lr: 0.000586   shrink: 0.99414
# 2020-11-04 00:33:01,505 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 168/719   Jobs: 1   Epoch: 18.67/80.0 (23.3% complete)   lr: 0.000584   shrink: 0.99416
# 2020-11-04 00:33:11,922 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 169/719   Jobs: 1   Epoch: 18.78/80.0 (23.5% complete)   lr: 0.000582   shrink: 0.99418
# 2020-11-04 00:33:20,794 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 170/719   Jobs: 1   Epoch: 18.89/80.0 (23.6% complete)   lr: 0.000581   shrink: 0.99419
# 2020-11-04 00:33:31,259 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 171/719   Jobs: 1   Epoch: 19.00/80.0 (23.8% complete)   lr: 0.000579   shrink: 0.99421
# 2020-11-04 00:33:38,072 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 172/719   Jobs: 1   Epoch: 19.11/80.0 (23.9% complete)   lr: 0.000577   shrink: 0.99423
# 2020-11-04 00:33:45,920 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 173/719   Jobs: 1   Epoch: 19.22/80.0 (24.0% complete)   lr: 0.000575   shrink: 0.99425
# 2020-11-04 00:33:52,527 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 174/719   Jobs: 1   Epoch: 19.33/80.0 (24.2% complete)   lr: 0.000573   shrink: 0.99427
# 2020-11-04 00:33:59,119 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 175/719   Jobs: 1   Epoch: 19.44/80.0 (24.3% complete)   lr: 0.000571   shrink: 0.99429
# 2020-11-04 00:34:07,617 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 176/719   Jobs: 1   Epoch: 19.56/80.0 (24.4% complete)   lr: 0.000570   shrink: 0.99430
# 2020-11-04 00:34:15,161 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 177/719   Jobs: 1   Epoch: 19.67/80.0 (24.6% complete)   lr: 0.000568   shrink: 0.99432
# 2020-11-04 00:34:25,646 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 178/719   Jobs: 1   Epoch: 19.78/80.0 (24.7% complete)   lr: 0.000566   shrink: 0.99434
# 2020-11-04 00:34:34,534 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 179/719   Jobs: 1   Epoch: 19.89/80.0 (24.9% complete)   lr: 0.000564   shrink: 0.99436
# 2020-11-04 00:34:45,024 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 180/719   Jobs: 1   Epoch: 20.00/80.0 (25.0% complete)   lr: 0.000562   shrink: 0.99438
# 2020-11-04 00:34:52,603 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 181/719   Jobs: 1   Epoch: 20.11/80.0 (25.1% complete)   lr: 0.000561   shrink: 0.99439
# 2020-11-04 00:35:00,429 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 182/719   Jobs: 1   Epoch: 20.22/80.0 (25.3% complete)   lr: 0.000559   shrink: 0.99441
# 2020-11-04 00:35:07,013 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 183/719   Jobs: 1   Epoch: 20.33/80.0 (25.4% complete)   lr: 0.000557   shrink: 0.99443
# 2020-11-04 00:35:13,713 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 184/719   Jobs: 1   Epoch: 20.44/80.0 (25.6% complete)   lr: 0.000555   shrink: 0.99445
# 2020-11-04 00:35:22,289 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 185/719   Jobs: 1   Epoch: 20.56/80.0 (25.7% complete)   lr: 0.000553   shrink: 0.99447
# 2020-11-04 00:35:29,845 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 186/719   Jobs: 1   Epoch: 20.67/80.0 (25.8% complete)   lr: 0.000552   shrink: 0.99448
# 2020-11-04 00:35:40,286 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 187/719   Jobs: 1   Epoch: 20.78/80.0 (26.0% complete)   lr: 0.000550   shrink: 0.99450
# 2020-11-04 00:35:49,225 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 188/719   Jobs: 1   Epoch: 20.89/80.0 (26.1% complete)   lr: 0.000548   shrink: 0.99452
# 2020-11-04 00:35:59,720 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 189/719   Jobs: 1   Epoch: 21.00/80.0 (26.2% complete)   lr: 0.000546   shrink: 0.99454
# 2020-11-04 00:36:06,539 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 190/719   Jobs: 1   Epoch: 21.11/80.0 (26.4% complete)   lr: 0.000545   shrink: 0.99455
# 2020-11-04 00:36:14,423 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 191/719   Jobs: 1   Epoch: 21.22/80.0 (26.5% complete)   lr: 0.000543   shrink: 0.99457
# 2020-11-04 00:36:20,976 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 192/719   Jobs: 1   Epoch: 21.33/80.0 (26.7% complete)   lr: 0.000541   shrink: 0.99459
# 2020-11-04 00:36:27,559 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 193/719   Jobs: 1   Epoch: 21.44/80.0 (26.8% complete)   lr: 0.000539   shrink: 0.99461
# 2020-11-04 00:36:36,082 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 194/719   Jobs: 1   Epoch: 21.56/80.0 (26.9% complete)   lr: 0.000538   shrink: 0.99462
# 2020-11-04 00:36:43,596 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 195/719   Jobs: 1   Epoch: 21.67/80.0 (27.1% complete)   lr: 0.000536   shrink: 0.99464
# 2020-11-04 00:36:54,076 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 196/719   Jobs: 1   Epoch: 21.78/80.0 (27.2% complete)   lr: 0.000534   shrink: 0.99466
# 2020-11-04 00:37:02,981 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 197/719   Jobs: 1   Epoch: 21.89/80.0 (27.4% complete)   lr: 0.000533   shrink: 0.99467
# 2020-11-04 00:37:13,454 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 198/719   Jobs: 1   Epoch: 22.00/80.0 (27.5% complete)   lr: 0.000531   shrink: 0.99469
# 2020-11-04 00:37:20,301 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 199/719   Jobs: 1   Epoch: 22.11/80.0 (27.6% complete)   lr: 0.000529   shrink: 0.99471
# 2020-11-04 00:37:28,159 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 200/719   Jobs: 1   Epoch: 22.22/80.0 (27.8% complete)   lr: 0.000527   shrink: 0.99473
# 2020-11-04 00:37:35,415 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 201/719   Jobs: 1   Epoch: 22.33/80.0 (27.9% complete)   lr: 0.000526   shrink: 0.99474
# 2020-11-04 00:37:42,029 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 202/719   Jobs: 1   Epoch: 22.44/80.0 (28.1% complete)   lr: 0.000524   shrink: 0.99476
# 2020-11-04 00:37:50,525 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 203/719   Jobs: 1   Epoch: 22.56/80.0 (28.2% complete)   lr: 0.000522   shrink: 0.99478
# 2020-11-04 00:37:58,090 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 204/719   Jobs: 1   Epoch: 22.67/80.0 (28.3% complete)   lr: 0.000521   shrink: 0.99479
# 2020-11-04 00:38:08,520 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 205/719   Jobs: 1   Epoch: 22.78/80.0 (28.5% complete)   lr: 0.000519   shrink: 0.99481
# 2020-11-04 00:38:17,475 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 206/719   Jobs: 1   Epoch: 22.89/80.0 (28.6% complete)   lr: 0.000517   shrink: 0.99483
# 2020-11-04 00:38:27,966 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 207/719   Jobs: 1   Epoch: 23.00/80.0 (28.8% complete)   lr: 0.000516   shrink: 0.99484
# 2020-11-04 00:38:34,768 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 208/719   Jobs: 1   Epoch: 23.11/80.0 (28.9% complete)   lr: 0.000514   shrink: 0.99486
# 2020-11-04 00:38:42,621 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 209/719   Jobs: 1   Epoch: 23.22/80.0 (29.0% complete)   lr: 0.000513   shrink: 0.99487
# 2020-11-04 00:38:49,189 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 210/719   Jobs: 1   Epoch: 23.33/80.0 (29.2% complete)   lr: 0.000511   shrink: 0.99489
# 2020-11-04 00:38:55,787 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 211/719   Jobs: 1   Epoch: 23.44/80.0 (29.3% complete)   lr: 0.000509   shrink: 0.99491
# 2020-11-04 00:39:04,296 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 212/719   Jobs: 1   Epoch: 23.56/80.0 (29.4% complete)   lr: 0.000508   shrink: 0.99492
# 2020-11-04 00:39:11,843 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 213/719   Jobs: 1   Epoch: 23.67/80.0 (29.6% complete)   lr: 0.000506   shrink: 0.99494
# 2020-11-04 00:39:22,395 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 214/719   Jobs: 1   Epoch: 23.78/80.0 (29.7% complete)   lr: 0.000504   shrink: 0.99496
# 2020-11-04 00:39:31,377 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 215/719   Jobs: 1   Epoch: 23.89/80.0 (29.9% complete)   lr: 0.000503   shrink: 0.99497
# 2020-11-04 00:39:41,921 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 216/719   Jobs: 1   Epoch: 24.00/80.0 (30.0% complete)   lr: 0.000501   shrink: 0.99499
# 2020-11-04 00:39:48,747 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 217/719   Jobs: 1   Epoch: 24.11/80.0 (30.1% complete)   lr: 0.000500   shrink: 0.99500
# 2020-11-04 00:39:56,564 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 218/719   Jobs: 1   Epoch: 24.22/80.0 (30.3% complete)   lr: 0.000498   shrink: 0.99502
# 2020-11-04 00:40:03,099 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 219/719   Jobs: 1   Epoch: 24.33/80.0 (30.4% complete)   lr: 0.000496   shrink: 0.99504
# 2020-11-04 00:40:09,687 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 220/719   Jobs: 1   Epoch: 24.44/80.0 (30.6% complete)   lr: 0.000495   shrink: 0.99505
# 2020-11-04 00:40:18,990 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 221/719   Jobs: 1   Epoch: 24.56/80.0 (30.7% complete)   lr: 0.000493   shrink: 0.99507
# 2020-11-04 00:40:26,626 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 222/719   Jobs: 1   Epoch: 24.67/80.0 (30.8% complete)   lr: 0.000492   shrink: 0.99508
# 2020-11-04 00:40:37,196 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 223/719   Jobs: 1   Epoch: 24.78/80.0 (31.0% complete)   lr: 0.000490   shrink: 0.99510
# 2020-11-04 00:40:46,173 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 224/719   Jobs: 1   Epoch: 24.89/80.0 (31.1% complete)   lr: 0.000489   shrink: 0.99511
# 2020-11-04 00:40:56,763 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 225/719   Jobs: 1   Epoch: 25.00/80.0 (31.2% complete)   lr: 0.000487   shrink: 0.99513
# 2020-11-04 00:41:03,585 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 226/719   Jobs: 1   Epoch: 25.11/80.0 (31.4% complete)   lr: 0.000485   shrink: 0.99515
# 2020-11-04 00:41:11,475 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 227/719   Jobs: 1   Epoch: 25.22/80.0 (31.5% complete)   lr: 0.000484   shrink: 0.99516
# 2020-11-04 00:41:18,109 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 228/719   Jobs: 1   Epoch: 25.33/80.0 (31.7% complete)   lr: 0.000482   shrink: 0.99518
# 2020-11-04 00:41:24,737 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 229/719   Jobs: 1   Epoch: 25.44/80.0 (31.8% complete)   lr: 0.000481   shrink: 0.99519
# 2020-11-04 00:41:33,283 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 230/719   Jobs: 1   Epoch: 25.56/80.0 (31.9% complete)   lr: 0.000479   shrink: 0.99521
# 2020-11-04 00:41:40,860 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 231/719   Jobs: 1   Epoch: 25.67/80.0 (32.1% complete)   lr: 0.000478   shrink: 0.99522
# 2020-11-04 00:41:51,451 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 232/719   Jobs: 1   Epoch: 25.78/80.0 (32.2% complete)   lr: 0.000476   shrink: 0.99524
# 2020-11-04 00:42:00,404 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 233/719   Jobs: 1   Epoch: 25.89/80.0 (32.4% complete)   lr: 0.000475   shrink: 0.99525
# 2020-11-04 00:42:10,964 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 234/719   Jobs: 1   Epoch: 26.00/80.0 (32.5% complete)   lr: 0.000473   shrink: 0.99527
# 2020-11-04 00:42:17,763 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 235/719   Jobs: 1   Epoch: 26.11/80.0 (32.6% complete)   lr: 0.000472   shrink: 0.99528
# 2020-11-04 00:42:25,646 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 236/719   Jobs: 1   Epoch: 26.22/80.0 (32.8% complete)   lr: 0.000470   shrink: 0.99530
# 2020-11-04 00:42:32,312 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 237/719   Jobs: 1   Epoch: 26.33/80.0 (32.9% complete)   lr: 0.000469   shrink: 0.99531
# 2020-11-04 00:42:38,881 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 238/719   Jobs: 1   Epoch: 26.44/80.0 (33.1% complete)   lr: 0.000467   shrink: 0.99533
# 2020-11-04 00:42:47,459 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 239/719   Jobs: 1   Epoch: 26.56/80.0 (33.2% complete)   lr: 0.000466   shrink: 0.99534
# 2020-11-04 00:42:55,117 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 240/719   Jobs: 1   Epoch: 26.67/80.0 (33.3% complete)   lr: 0.000464   shrink: 0.99536
# 2020-11-04 00:43:06,352 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 241/719   Jobs: 1   Epoch: 26.78/80.0 (33.5% complete)   lr: 0.000463   shrink: 0.99537
# 2020-11-04 00:43:15,272 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 242/719   Jobs: 1   Epoch: 26.89/80.0 (33.6% complete)   lr: 0.000461   shrink: 0.99539
# 2020-11-04 00:43:25,815 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 243/719   Jobs: 1   Epoch: 27.00/80.0 (33.8% complete)   lr: 0.000460   shrink: 0.99540
# 2020-11-04 00:43:32,678 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 244/719   Jobs: 1   Epoch: 27.11/80.0 (33.9% complete)   lr: 0.000458   shrink: 0.99542
# 2020-11-04 00:43:40,511 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 245/719   Jobs: 1   Epoch: 27.22/80.0 (34.0% complete)   lr: 0.000457   shrink: 0.99543
# 2020-11-04 00:43:47,088 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 246/719   Jobs: 1   Epoch: 27.33/80.0 (34.2% complete)   lr: 0.000455   shrink: 0.99545
# 2020-11-04 00:43:53,744 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 247/719   Jobs: 1   Epoch: 27.44/80.0 (34.3% complete)   lr: 0.000454   shrink: 0.99546
# 2020-11-04 00:44:02,252 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 248/719   Jobs: 1   Epoch: 27.56/80.0 (34.4% complete)   lr: 0.000452   shrink: 0.99548
# 2020-11-04 00:44:09,810 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 249/719   Jobs: 1   Epoch: 27.67/80.0 (34.6% complete)   lr: 0.000451   shrink: 0.99549
# 2020-11-04 00:44:20,319 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 250/719   Jobs: 1   Epoch: 27.78/80.0 (34.7% complete)   lr: 0.000450   shrink: 0.99550
# 2020-11-04 00:44:29,271 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 251/719   Jobs: 1   Epoch: 27.89/80.0 (34.9% complete)   lr: 0.000448   shrink: 0.99552
# 2020-11-04 00:44:39,791 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 252/719   Jobs: 1   Epoch: 28.00/80.0 (35.0% complete)   lr: 0.000447   shrink: 0.99553
# 2020-11-04 00:44:46,636 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 253/719   Jobs: 1   Epoch: 28.11/80.0 (35.1% complete)   lr: 0.000445   shrink: 0.99555
# 2020-11-04 00:44:54,501 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 254/719   Jobs: 1   Epoch: 28.22/80.0 (35.3% complete)   lr: 0.000444   shrink: 0.99556
# 2020-11-04 00:45:01,091 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 255/719   Jobs: 1   Epoch: 28.33/80.0 (35.4% complete)   lr: 0.000442   shrink: 0.99558
# ...
# 2020-11-04 01:36:34,025 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 630/719   Jobs: 1   Epoch: 70.00/80.0 (87.5% complete)   lr: 0.000133   shrink: 0.99867
# 2020-11-04 01:36:40,815 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 631/719   Jobs: 1   Epoch: 70.11/80.0 (87.6% complete)   lr: 0.000133   shrink: 0.99867
# 2020-11-04 01:36:48,680 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 632/719   Jobs: 1   Epoch: 70.22/80.0 (87.8% complete)   lr: 0.000133   shrink: 0.99867
# 2020-11-04 01:36:55,244 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 633/719   Jobs: 1   Epoch: 70.33/80.0 (87.9% complete)   lr: 0.000132   shrink: 0.99868
# 2020-11-04 01:37:01,832 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 634/719   Jobs: 1   Epoch: 70.44/80.0 (88.1% complete)   lr: 0.000132   shrink: 0.99868
# 2020-11-04 01:37:10,331 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 635/719   Jobs: 1   Epoch: 70.56/80.0 (88.2% complete)   lr: 0.000131   shrink: 0.99869
# 2020-11-04 01:37:17,866 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 636/719   Jobs: 1   Epoch: 70.67/80.0 (88.3% complete)   lr: 0.000131   shrink: 0.99869
# 2020-11-04 01:37:28,368 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 637/719   Jobs: 1   Epoch: 70.78/80.0 (88.5% complete)   lr: 0.000130   shrink: 0.99870
# 2020-11-04 01:37:37,291 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 638/719   Jobs: 1   Epoch: 70.89/80.0 (88.6% complete)   lr: 0.000130   shrink: 0.99870
# 2020-11-04 01:37:47,740 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 639/719   Jobs: 1   Epoch: 71.00/80.0 (88.8% complete)   lr: 0.000130   shrink: 0.99870
# 2020-11-04 01:37:54,624 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 640/719   Jobs: 1   Epoch: 71.11/80.0 (88.9% complete)   lr: 0.000129   shrink: 0.99871
# 2020-11-04 01:38:03,215 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 641/719   Jobs: 1   Epoch: 71.22/80.0 (89.0% complete)   lr: 0.000129   shrink: 0.99871
# 2020-11-04 01:38:09,779 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 642/719   Jobs: 1   Epoch: 71.33/80.0 (89.2% complete)   lr: 0.000128   shrink: 0.99872
# 2020-11-04 01:38:16,373 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 643/719   Jobs: 1   Epoch: 71.44/80.0 (89.3% complete)   lr: 0.000128   shrink: 0.99872
# 2020-11-04 01:38:24,822 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 644/719   Jobs: 1   Epoch: 71.56/80.0 (89.4% complete)   lr: 0.000128   shrink: 0.99872
# 2020-11-04 01:38:32,359 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 645/719   Jobs: 1   Epoch: 71.67/80.0 (89.6% complete)   lr: 0.000127   shrink: 0.99873
# 2020-11-04 01:38:42,843 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 646/719   Jobs: 1   Epoch: 71.78/80.0 (89.7% complete)   lr: 0.000127   shrink: 0.99873
# 2020-11-04 01:38:51,728 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 647/719   Jobs: 1   Epoch: 71.89/80.0 (89.9% complete)   lr: 0.000126   shrink: 0.99874
# 2020-11-04 01:39:02,148 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 648/719   Jobs: 1   Epoch: 72.00/80.0 (90.0% complete)   lr: 0.000126   shrink: 0.99874
# 2020-11-04 01:39:08,980 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 649/719   Jobs: 1   Epoch: 72.11/80.0 (90.1% complete)   lr: 0.000125   shrink: 0.99875
# 2020-11-04 01:39:16,807 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 650/719   Jobs: 1   Epoch: 72.22/80.0 (90.3% complete)   lr: 0.000125   shrink: 0.99875
# 2020-11-04 01:39:23,408 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 651/719   Jobs: 1   Epoch: 72.33/80.0 (90.4% complete)   lr: 0.000125   shrink: 0.99875
# 2020-11-04 01:39:30,002 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 652/719   Jobs: 1   Epoch: 72.44/80.0 (90.6% complete)   lr: 0.000124   shrink: 0.99876
# 2020-11-04 01:39:38,478 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 653/719   Jobs: 1   Epoch: 72.56/80.0 (90.7% complete)   lr: 0.000124   shrink: 0.99876
# 2020-11-04 01:39:46,029 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 654/719   Jobs: 1   Epoch: 72.67/80.0 (90.8% complete)   lr: 0.000123   shrink: 0.99877
# 2020-11-04 01:39:56,521 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 655/719   Jobs: 1   Epoch: 72.78/80.0 (91.0% complete)   lr: 0.000123   shrink: 0.99877
# 2020-11-04 01:40:05,448 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 656/719   Jobs: 1   Epoch: 72.89/80.0 (91.1% complete)   lr: 0.000123   shrink: 0.99877
# 2020-11-04 01:40:15,963 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 657/719   Jobs: 1   Epoch: 73.00/80.0 (91.2% complete)   lr: 0.000122   shrink: 0.99878
# 2020-11-04 01:40:22,748 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 658/719   Jobs: 1   Epoch: 73.11/80.0 (91.4% complete)   lr: 0.000122   shrink: 0.99878
# 2020-11-04 01:40:30,528 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 659/719   Jobs: 1   Epoch: 73.22/80.0 (91.5% complete)   lr: 0.000122   shrink: 0.99878
# 2020-11-04 01:40:37,078 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 660/719   Jobs: 1   Epoch: 73.33/80.0 (91.7% complete)   lr: 0.000121   shrink: 0.99879
# 2020-11-04 01:40:44,417 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 661/719   Jobs: 1   Epoch: 73.44/80.0 (91.8% complete)   lr: 0.000121   shrink: 0.99879
# 2020-11-04 01:40:52,973 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 662/719   Jobs: 1   Epoch: 73.56/80.0 (91.9% complete)   lr: 0.000120   shrink: 0.99880
# 2020-11-04 01:41:00,492 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 663/719   Jobs: 1   Epoch: 73.67/80.0 (92.1% complete)   lr: 0.000120   shrink: 0.99880
# 2020-11-04 01:41:10,872 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 664/719   Jobs: 1   Epoch: 73.78/80.0 (92.2% complete)   lr: 0.000120   shrink: 0.99880
# 2020-11-04 01:41:19,731 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 665/719   Jobs: 1   Epoch: 73.89/80.0 (92.4% complete)   lr: 0.000119   shrink: 0.99881
# 2020-11-04 01:41:30,244 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 666/719   Jobs: 1   Epoch: 74.00/80.0 (92.5% complete)   lr: 0.000119   shrink: 0.99881
# 2020-11-04 01:41:37,030 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 667/719   Jobs: 1   Epoch: 74.11/80.0 (92.6% complete)   lr: 0.000118   shrink: 0.99882
# 2020-11-04 01:41:44,813 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 668/719   Jobs: 1   Epoch: 74.22/80.0 (92.8% complete)   lr: 0.000118   shrink: 0.99882
# 2020-11-04 01:41:51,393 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 669/719   Jobs: 1   Epoch: 74.33/80.0 (92.9% complete)   lr: 0.000118   shrink: 0.99882
# 2020-11-04 01:41:57,963 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 670/719   Jobs: 1   Epoch: 74.44/80.0 (93.1% complete)   lr: 0.000117   shrink: 0.99883
# 2020-11-04 01:42:06,534 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 671/719   Jobs: 1   Epoch: 74.56/80.0 (93.2% complete)   lr: 0.000117   shrink: 0.99883
# 2020-11-04 01:42:14,059 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 672/719   Jobs: 1   Epoch: 74.67/80.0 (93.3% complete)   lr: 0.000117   shrink: 0.99883
# 2020-11-04 01:42:24,424 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 673/719   Jobs: 1   Epoch: 74.78/80.0 (93.5% complete)   lr: 0.000116   shrink: 0.99884
# 2020-11-04 01:42:33,312 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 674/719   Jobs: 1   Epoch: 74.89/80.0 (93.6% complete)   lr: 0.000116   shrink: 0.99884
# 2020-11-04 01:42:43,749 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 675/719   Jobs: 1   Epoch: 75.00/80.0 (93.8% complete)   lr: 0.000115   shrink: 0.99885
# 2020-11-04 01:42:50,575 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 676/719   Jobs: 1   Epoch: 75.11/80.0 (93.9% complete)   lr: 0.000115   shrink: 0.99885
# 2020-11-04 01:42:58,389 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 677/719   Jobs: 1   Epoch: 75.22/80.0 (94.0% complete)   lr: 0.000115   shrink: 0.99885
# 2020-11-04 01:43:04,927 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 678/719   Jobs: 1   Epoch: 75.33/80.0 (94.2% complete)   lr: 0.000114   shrink: 0.99886
# 2020-11-04 01:43:11,536 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 679/719   Jobs: 1   Epoch: 75.44/80.0 (94.3% complete)   lr: 0.000114   shrink: 0.99886
# 2020-11-04 01:43:20,092 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 680/719   Jobs: 1   Epoch: 75.56/80.0 (94.4% complete)   lr: 0.000114   shrink: 0.99886
# 2020-11-04 01:43:28,303 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 681/719   Jobs: 1   Epoch: 75.67/80.0 (94.6% complete)   lr: 0.000113   shrink: 0.99887
# 2020-11-04 01:43:38,758 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 682/719   Jobs: 1   Epoch: 75.78/80.0 (94.7% complete)   lr: 0.000113   shrink: 0.99887
# 2020-11-04 01:43:47,654 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 683/719   Jobs: 1   Epoch: 75.89/80.0 (94.9% complete)   lr: 0.000113   shrink: 0.99887
# 2020-11-04 01:43:58,114 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 684/719   Jobs: 1   Epoch: 76.00/80.0 (95.0% complete)   lr: 0.000112   shrink: 0.99888
# 2020-11-04 01:44:04,926 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 685/719   Jobs: 1   Epoch: 76.11/80.0 (95.1% complete)   lr: 0.000112   shrink: 0.99888
# 2020-11-04 01:44:12,747 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 686/719   Jobs: 1   Epoch: 76.22/80.0 (95.3% complete)   lr: 0.000111   shrink: 0.99889
# 2020-11-04 01:44:19,323 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 687/719   Jobs: 1   Epoch: 76.33/80.0 (95.4% complete)   lr: 0.000111   shrink: 0.99889
# 2020-11-04 01:44:25,962 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 688/719   Jobs: 1   Epoch: 76.44/80.0 (95.6% complete)   lr: 0.000111   shrink: 0.99889
# 2020-11-04 01:44:34,479 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 689/719   Jobs: 1   Epoch: 76.56/80.0 (95.7% complete)   lr: 0.000110   shrink: 0.99890
# 2020-11-04 01:44:42,449 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 690/719   Jobs: 1   Epoch: 76.67/80.0 (95.8% complete)   lr: 0.000110   shrink: 0.99890
# 2020-11-04 01:44:52,930 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 691/719   Jobs: 1   Epoch: 76.78/80.0 (96.0% complete)   lr: 0.000110   shrink: 0.99890
# 2020-11-04 01:45:01,856 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 692/719   Jobs: 1   Epoch: 76.89/80.0 (96.1% complete)   lr: 0.000109   shrink: 0.99891
# 2020-11-04 01:45:12,305 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 693/719   Jobs: 1   Epoch: 77.00/80.0 (96.2% complete)   lr: 0.000109   shrink: 0.99891
# 2020-11-04 01:45:19,075 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 694/719   Jobs: 1   Epoch: 77.11/80.0 (96.4% complete)   lr: 0.000109   shrink: 0.99891
# 2020-11-04 01:45:26,881 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 695/719   Jobs: 1   Epoch: 77.22/80.0 (96.5% complete)   lr: 0.000108   shrink: 0.99892
# 2020-11-04 01:45:33,471 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 696/719   Jobs: 1   Epoch: 77.33/80.0 (96.7% complete)   lr: 0.000108   shrink: 0.99892
# 2020-11-04 01:45:40,082 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 697/719   Jobs: 1   Epoch: 77.44/80.0 (96.8% complete)   lr: 0.000108   shrink: 0.99892
# 2020-11-04 01:45:48,626 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 698/719   Jobs: 1   Epoch: 77.56/80.0 (96.9% complete)   lr: 0.000107   shrink: 0.99893
# 2020-11-04 01:45:56,204 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 699/719   Jobs: 1   Epoch: 77.67/80.0 (97.1% complete)   lr: 0.000107   shrink: 0.99893
# 2020-11-04 01:46:06,653 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 700/719   Jobs: 1   Epoch: 77.78/80.0 (97.2% complete)   lr: 0.000107   shrink: 0.99893
# 2020-11-04 01:46:16,300 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 701/719   Jobs: 1   Epoch: 77.89/80.0 (97.4% complete)   lr: 0.000106   shrink: 0.99894
# 2020-11-04 01:46:26,787 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 702/719   Jobs: 1   Epoch: 78.00/80.0 (97.5% complete)   lr: 0.000106   shrink: 0.99894
# 2020-11-04 01:46:33,576 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 703/719   Jobs: 1   Epoch: 78.11/80.0 (97.6% complete)   lr: 0.000106   shrink: 0.99894
# 2020-11-04 01:46:41,408 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 704/719   Jobs: 1   Epoch: 78.22/80.0 (97.8% complete)   lr: 0.000105   shrink: 0.99895
# 2020-11-04 01:46:47,905 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 705/719   Jobs: 1   Epoch: 78.33/80.0 (97.9% complete)   lr: 0.000105   shrink: 0.99895
# 2020-11-04 01:46:54,547 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 706/719   Jobs: 1   Epoch: 78.44/80.0 (98.1% complete)   lr: 0.000105   shrink: 0.99895
# 2020-11-04 01:47:03,006 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 707/719   Jobs: 1   Epoch: 78.56/80.0 (98.2% complete)   lr: 0.000104   shrink: 0.99896
# 2020-11-04 01:47:10,620 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 708/719   Jobs: 1   Epoch: 78.67/80.0 (98.3% complete)   lr: 0.000104   shrink: 0.99896
# 2020-11-04 01:47:21,058 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 709/719   Jobs: 1   Epoch: 78.78/80.0 (98.5% complete)   lr: 0.000104   shrink: 0.99896
# 2020-11-04 01:47:29,940 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 710/719   Jobs: 1   Epoch: 78.89/80.0 (98.6% complete)   lr: 0.000103   shrink: 0.99897
# 2020-11-04 01:47:40,372 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 711/719   Jobs: 1   Epoch: 79.00/80.0 (98.8% complete)   lr: 0.000103   shrink: 0.99897
# 2020-11-04 01:47:47,150 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 712/719   Jobs: 1   Epoch: 79.11/80.0 (98.9% complete)   lr: 0.000103   shrink: 0.99897
# 2020-11-04 01:47:54,976 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 713/719   Jobs: 1   Epoch: 79.22/80.0 (99.0% complete)   lr: 0.000102   shrink: 0.99898
# 2020-11-04 01:48:01,496 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 714/719   Jobs: 1   Epoch: 79.33/80.0 (99.2% complete)   lr: 0.000102   shrink: 0.99898
# 2020-11-04 01:48:08,123 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 715/719   Jobs: 1   Epoch: 79.44/80.0 (99.3% complete)   lr: 0.000102   shrink: 0.99898
# 2020-11-04 01:48:16,584 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 716/719   Jobs: 1   Epoch: 79.56/80.0 (99.4% complete)   lr: 0.000101   shrink: 0.99899
# 2020-11-04 01:48:24,096 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 717/719   Jobs: 1   Epoch: 79.67/80.0 (99.6% complete)   lr: 0.000101   shrink: 0.99899
# 2020-11-04 01:48:34,513 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 718/719   Jobs: 1   Epoch: 79.78/80.0 (99.7% complete)   lr: 0.000101   shrink: 0.99899
# 2020-11-04 01:48:43,405 [steps/nnet3/train_raw_dnn.py:391 - train - INFO ] Iter: 719/719   Jobs: 1   Epoch: 79.89/80.0 (99.9% complete)   lr: 0.000100   shrink: 0.99900
# 2020-11-04 01:48:53,885 [steps/nnet3/train_raw_dnn.py:443 - train - INFO ] Doing final combination to produce final.raw
# 2020-11-04 01:48:53,886 [steps/libs/nnet3/train/frame_level_objf/common.py:491 - combine_models - INFO ] Combining {701, 702, 703, 704, 705, 706, 707, 708, 709, 710, 711, 712, 713, 714, 715, 716, 717, 718, 719, 720} models.
# 2020-11-04 01:49:34,456 [steps/nnet3/train_raw_dnn.py:465 - train - INFO ] Cleaning up the experiment directory exp/xvector_nnet_1a
# exp/xvector_nnet_1a: num-iters=720 nj=1..1 num-params=4.6M dim=23->340 combine=-0.45->-0.45 (over 1) loglike:train/valid[478,719]=(-0.44,-0.48/-0.56,-0.59) accuracy:train/valid[478,719]=(0.927,0.931/0.919,0.915)
# 耗时： 6010.162974834442

# %% [markdown]
# **第七步：** 使用x-vector模型,提取embedding
#
#     1.（train_combined）利用训练好的模型，提取训练集的x-vector 输出位置：exp/xvectors_train_combined
#     2. (train_combined) 对数据进行LDA降维  输出位置：exp/xvectors_train_combined/transform.mat
#     3. (train_combined) 对数据进行PLDA建模 输出位置：exp/xvectors_train_combined/plda

# %%
ss= time.time()

# !chmod +x new_07_train.sh
# !bash new_07_train.sh

print("耗时：",time.time() - ss)
# Out:
# sid/nnet3/xvector/extract_xvectors.sh --cmd run.pl --mem 10G --mem 12G --nj 20 exp/xvector_nnet_1a data/train_combined exp/xvectors_train_combined
# sid/nnet3/xvector/extract_xvectors.sh: using exp/xvector_nnet_1a/extract.config to extract xvectors
# sid/nnet3/xvector/extract_xvectors.sh: extracting xvectors for data/train_combined
# sid/nnet3/xvector/extract_xvectors.sh: extracting xvectors from nnet
# sid/nnet3/xvector/extract_xvectors.sh: combining xvectors across jobs
# sid/nnet3/xvector/extract_xvectors.sh: computing mean of xvectors for each speaker
# 耗时： 4647.765430927277

# %% [markdown]
# **第八步：** 从测试集中划分训练集和测试集
#
#     1.注意线程数量。
#     2.划分注册语音和测试语音
#     3.分别提取他们的x-vector

# %%
ss= time.time()

# !chmod +x new_08_create_task.sh
# !bash new_08_create_task.sh

print("耗时：",time.time() - ss)
# Out:
# utils/fix_data_dir.sh: file data/test/enroll/utt2spk is not in sorted order or not unique, sorting it
# fix_data_dir.sh: kept all 60 utterances.
# fix_data_dir.sh: old files are kept in data/test/enroll/.backup
# utils/fix_data_dir.sh: file data/test/eval/utt2spk is not in sorted order or not unique, sorting it
# fix_data_dir.sh: kept all 7116 utterances.
# fix_data_dir.sh: old files are kept in data/test/eval/.backup
# sid/nnet3/xvector/extract_xvectors.sh --cmd run.pl --mem 10G --mem 10G --nj 20 exp/xvector_nnet_1a data/test exp/xvector_nnet_1a/xvectors_test
# sid/nnet3/xvector/extract_xvectors.sh: using exp/xvector_nnet_1a/extract.config to extract xvectors
# sid/nnet3/xvector/extract_xvectors.sh: extracting xvectors for data/test
# sid/nnet3/xvector/extract_xvectors.sh: extracting xvectors from nnet
# sid/nnet3/xvector/extract_xvectors.sh: combining xvectors across jobs
# sid/nnet3/xvector/extract_xvectors.sh: computing mean of xvectors for each speaker
# 耗时： 217.85754323005676

# %% [markdown]
# **第九步：** 计算结果
#
#     1.提取测试集的表征，因为测试集的数量比较少，使用40进程容易出错。
#     2.利用训练好的plda，以及测试集的x-vector生成每一对的得分。
#     3.计算EER，minDCF

# %%
# !chmod +x new_09_result.sh
# !bash new_09_result.sh
# Out:
# EER: 0.6745%
# minDCF(p-target=0.01): 0.1043
# minDCF(p-target=0.001): 0.1816
